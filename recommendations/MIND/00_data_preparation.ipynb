# %%
import pandas as pd

# %% [markdown]
# # Data Schema
#
# ## 1. Behavior Data
#
# This file records the user click histories and impression logs.
#
# | Field | Description | Format / Example |
# | :--- | :--- | :--- |
# | **Impression ID** | The unique ID of an impression. | `1` |
# | **User ID** | The anonymous ID of a user. | `U131` |
# | **Time** | The impression time. | `11/11/2019 09:05:46 AM` |
# | **History** | The news click history of this user before this impression. The clicked news articles are ordered by time. | List of News IDs (e.g., `N12 N34 N56`) |
# | **Impressions** | List of news displayed in this impression and user's click behaviors on them (`1` for click, `0` for non-click). The order of news has been shuffled. | `N12-1 N34-0 N56-0` |
#
# ---
#
# ## 2. News Data
#
# This file contains the detailed information of news articles.
#
# | Field | Description |
# | :--- | :--- |
# | **News ID** | The unique ID of the news article. |
# | **Category** | The category of the news (e.g., sports, lifestyle). |
# | **SubCategory** | The subcategory of the news. |
# | **Title** | The title of the news article. |
# | **Abstract** | The abstract of the news article. |
# | **URL** | The URL of the news article (Note: Original URLs may have expired). |
# | **Title Entities** | Entities contained in the title of this news. |
# | **Abstract Entities** | Entities contained in the abstract of this news. |

# %% [markdown]
# ## Load the data first

# %%
behavior_cols = ['impression_id','user_id','time','history','impressions']
news_cols = ['news_id','category','subcategory','title','abstract','url','title_entities','abstract_entities']

# 2 vec files are embedding vectors with first column is id/entity

# %%
df_news = pd.read_csv('MINDsmall_train/news.tsv', sep='\t', header=None, names=news_cols)
df_behavior = pd.read_csv('MINDsmall_train/behaviors.tsv', sep='\t', header=None, names=behavior_cols)

# %%
df_behavior.to_parquet('data/behaviors.parquet', index=False)
df_news.to_parquet('data/news.parquet', index=False)

# %%
df_news
# Out:
#       news_id   category        subcategory  \
# 0      N55528  lifestyle    lifestyleroyals
# 1      N19639     health         weightloss
# 2      N61837       news          newsworld
# 3      N53526     health             voices
# 4      N38324     health            medical
# ...       ...        ...                ...
# 51277  N16909    weather  weathertopstories
# 51278  N47585  lifestyle    lifestylefamily
# 51279   N7482     sports        more_sports
# 51280  N34418     sports         soccer_epl
# 51281  N44276      autos        autossports
#
#                                                    title  \
# 0      The Brands Queen Elizabeth, Prince Charles, an...
# 1                          50 Worst Habits For Belly Fat
# 2      The Cost of Trump's Aid Freeze in the Trenches...
# 3      I Was An NBA Wife. Here's How It Affected My M...
# 4      How to Get Rid of Skin Tags, According to a De...
# ...                                                  ...
# ...

# %%
pd.DataFrame(df_news[['category','subcategory']].value_counts(dropna=False))
# Out:
#                                   count
# category      subcategory
# news          newsus               6564
# sports        football_nfl         5420
# news          newspolitics         2826
#               newscrime            2254
# weather       weathertopstories    2047
# ...                                 ...
# northamerica  northamerica-video      1
# autos         autosmidsize            1
# entertainment entertainmenttv         1
# autos         autoslosangeles         1
# entertainment celebhub                1
#
# [283 rows x 1 columns]

# %%
df_news['title_entities'][0]
# Out:
# '[{"Label": "Prince Philip, Duke of Edinburgh", "Type": "P", "WikidataId": "Q80976", "Confidence": 1.0, "OccurrenceOffsets": [48], "SurfaceForms": ["Prince Philip"]}, {"Label": "Charles, Prince of Wales", "Type": "P", "WikidataId": "Q43274", "Confidence": 1.0, "OccurrenceOffsets": [28], "SurfaceForms": ["Prince Charles"]}, {"Label": "Elizabeth II", "Type": "P", "WikidataId": "Q9682", "Confidence": 0.97, "OccurrenceOffsets": [11], "SurfaceForms": ["Queen Elizabeth"]}]'

# %%
df_behavior
# Out:
#         impression_id user_id                    time  \
# 0                   1  U13740   11/11/2019 9:05:58 AM
# 1                   2  U91836   11/12/2019 6:11:30 PM
# 2                   3  U73700   11/14/2019 7:01:48 AM
# 3                   4  U34670   11/11/2019 5:28:05 AM
# 4                   5   U8125   11/12/2019 4:11:21 PM
# ...               ...     ...                     ...
# 156960         156961  U21593  11/14/2019 10:24:05 PM
# 156961         156962  U10123   11/13/2019 6:57:04 AM
# 156962         156963  U75630  11/14/2019 10:58:13 AM
# 156963         156964  U44625   11/13/2019 2:57:02 PM
# 156964         156965  U64800   11/14/2019 3:25:49 PM
#
#                                                   history  \
# 0       N55189 N42782 N34694 N45794 N18445 N63302 N104...
# 1       N31739 N6072 N63045 N23979 N35656 N43353 N8129...
# 2       N10732 N25792 N7563 N21087 N41087 N5445 N60384...
# 3       N45729 N2203 N871 N53880 N41375 N43142 N33013 ...
# ...

# %%
import pandas as pd

# %%
pd.read_parquet('data/split/val/ctr_part_0004.parquet')
# Out:
#          user_id  item_id  click  video_category  gender  age  hist_1  hist_2  \
# 0         289826    12700      0               0       1    2   32396   46705
# 1         289826    20802      0               1       1    2   32396   46705
# 2         289826   180846      0               1       1    2   32396   46705
# 3         289826    28564      0               1       1    2   32396   46705
# 4         289826    22698      0               0       1    2   32396   46705
# ...          ...      ...    ...             ...     ...  ...     ...     ...
# 2017334   371172  3033966      1               0       1    3    3344  127431
# 2017335   371172  3034684      1               0       1    3    3344  127431
# 2017336   371172  3033526      1               0       1    3    3344  127431
# 2017337   371172  3034456      1               0       1    3    3344  127431
# 2017338   371172  3034830      0               1       1    3    3344  127431
#
# ...

# %%
import pandas as pd

# %%
df_1=pd.read_parquet('data/split/val/ctr_part_0004.parquet')

# %%
df_1.head(20)
# Out:
#     user_id  item_id  click  follow  like  share  video_category  gender  age  \
# 0    289826    12700      0       0     0      0               0       1    2
# 1    289826    20802      0       0     0      0               1       1    2
# 2    289826   180846      0       0     0      0               1       1    2
# 3    289826    28564      0       0     0      0               1       1    2
# 4    289826    22698      0       0     0      1               0       1    2
# 5    289826    11513      0       0     0      0               1       1    2
# 6    289826    33703      0       0     0      0               0       1    2
# 7    289826   122536      0       0     0      0               1       1    2
# 8    289826    24176      0       0     0      0               0       1    2
# 9    289826    10662      0       0     0      0               1       1    2
# 10   289826    19967      0       0     0      0               1       1    2
# ...
